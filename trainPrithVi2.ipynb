# %%
import rasterio
import torch
from terratorch.registry import BACKBONE_REGISTRY
from torch.utils.data import Dataset, DataLoader
import rasterio
import numpy as np
from sklearn.model_selection import train_test_split
import segmentation_models_pytorch as smp
file_path = '/mnt/ADV_VISION/Dataset/v1.1/data/flood_events/HandLabeled/LabelHand/Ghana_7496_LabelHand.tif'  # Replace with your actual file path

with rasterio.open(file_path) as src:
    print("Number of bands:", src.count)
    print("Height (pixels):", src.height)
    print("Width (pixels):", src.width)
    print("Shape (bands, height, width):", (src.count, src.height, src.width))
# Out:
# Number of bands: 1
# Height (pixels): 512
# Width (pixels): 512
# Shape (bands, height, width): (1, 512, 512)

# %%
import os

label_dir = '/mnt/ADV_VISION/Dataset/v1.1/data/flood_events/HandLabeled/LabelHand/'
label_files = [os.path.join(label_dir, f) for f in os.listdir(label_dir) if f.endswith('.tif')]
print("Number of label files:", len(label_files))
print("Example file:", label_files[0])
# Out:
# Number of label files: 446
# Example file: /mnt/ADV_VISION/Dataset/v1.1/data/flood_events/HandLabeled/LabelHand/India_1050276_LabelHand.tif

# %%
import rasterio
import matplotlib.pyplot as plt

with rasterio.open(label_files[1]) as src:
    label = src.read(1)  # Read first (and only) band
    print("Label shape:", label.shape)
    print("Unique values in mask:", set(label.flatten()))

plt.figure(figsize=(6,6))
plt.imshow(label, cmap='gray')
plt.title('LabelHand Mask Example')
plt.colorbar(label='Class')
plt.show()
# Out:
# Label shape: (512, 512)
# Unique values in mask: {np.int16(0), np.int16(1), np.int16(-1)}

# %%
import csv
import os
def read_prithvi_bands_from_dir(dir_path,mask_dir_path ,csv_path):
    images = []
    masks = []

    with open(csv_path, newline='') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            if len(row) >= 2:
                input_rel, mask_rel = row[0], row[1]
                input_rel = input_rel.replace("S1Hand", "S2Hand")


                input_full = os.path.join(dir_path, input_rel)
                mask_full = os.path.join(mask_dir_path, mask_rel)
                with rasterio.open(input_full) as src:
                    img = src.read([2, 3, 4, 9, 11, 12]) 
                    img = img / 10000.0  
                    images.append(img)
                with rasterio.open(mask_full) as src:
                    mask = src.read(1)
                    mask = (mask).astype(np.int64)  
                    masks.append(mask)

    if images:
        print('Number of images read:', len(images))
        print('Shape of first image:', images[0].shape)  
    else:
        print('No images found in directory')
    if masks:
        print('Number of masks read:', len(masks))
        print('Shape of first mask:', masks[0].shape)  
        print('Unique values in first mask:', np.unique(masks[0]))  
    else:
        print('No masks found in directory')
    return images, masks

# %%
img_path='/mnt/ADV_VISION/Dataset/v1.1/data/flood_events/HandLabeled/S2Hand'
masks_path='/mnt/ADV_VISION/Dataset/v1.1/data/flood_events/HandLabeled/LabelHand'
train_img, train_mask = read_prithvi_bands_from_dir(img_path, masks_path,'/mnt/ADV_VISION/v1.1C/splits/flood_handlabeled/flood_train_data.csv')
val_img, val_mask = read_prithvi_bands_from_dir(img_path, masks_path,'/mnt/ADV_VISION/v1.1C/splits/flood_handlabeled/flood_valid_data.csv')
test_img, test_mask = read_prithvi_bands_from_dir(img_path, masks_path,'/mnt/ADV_VISION/v1.1C/splits/flood_handlabeled/flood_test_data.csv')
# Out:
# Number of images read: 252
# Shape of first image: (6, 512, 512)
# Number of masks read: 252
# Shape of first mask: (512, 512)
# Unique values in first mask: [-1  0  1]
# Number of images read: 89
# Shape of first image: (6, 512, 512)
# Number of masks read: 89
# Shape of first mask: (512, 512)
# Unique values in first mask: [-1]
# Number of images read: 90
# Shape of first image: (6, 512, 512)
# Number of masks read: 90
# Shape of first mask: (512, 512)
# Unique values in first mask: [-1  0  1]

# %%
import matplotlib.pyplot as plt

def plot_sensitivity(miou_histories, labels):

    for miou, label in zip(miou_histories, labels):
        plt.plot(miou, label=label)
    plt.xlabel('Epoch')
    plt.ylabel('Validation mIoU')
    plt.title('Sensitivity Analysis: mIoU vs Training Data Amount')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import torch
import torch.nn as nn
import numpy as np
from terratorch.registry import FULL_MODEL_REGISTRY


def compute_iou(output, target):
    output = output.flatten()
    target = target.flatten()
    
    # Mask for classes 1 and 2 in TARGET (ignore 0)
    mask = (target == 1) | (target == 2)
    
    # Apply mask to both tensors
    output_filtered = output[mask]
    target_filtered = target[mask]
    
    intersection = torch.sum(output_filtered == target_filtered)
    union = output_filtered.numel()  # Total masked pixels
    
    return (intersection + 1e-7) / (union + 1e-7)



def train_model(
    train_imgs, train_masks, 
    val_imgs, val_masks, 
    model_class, 
    num_classes=3, 
    epochs=100, 
    lr=1e-3, 
    loss_fn=None, 
    optimizer_class=None,
    device=None
):
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = FULL_MODEL_REGISTRY.build(
        "prithvi_eo_v2_300_mae",
        pretrained=True,
        pretrained_cfg_name="Prithvi-EO-V2-300M-TL-Sen1Floods11.pt",
        checkpoint_path="/mnt/ADV_VISION/Prithvi-EO-2.0-300M-TL-Sen1Floods11"
    ).to("cuda")
    if loss_fn is None:
        loss_fn = nn.CrossEntropyLoss(ignore_index=-1)
    if optimizer_class is None:
        optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
    else:
        optimizer = optimizer_class(model.parameters(), lr=lr)
    
    miou_history = []
    best_miou = 0.0
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        for img, mask in zip(train_imgs, train_masks):
            inputs = torch.tensor(img, device=device).float().unsqueeze(0)  
            targets = torch.tensor(mask+1, device=device).long().unsqueeze(0)  
            unique_classes = torch.unique(targets)
            # print(unique_classes)
            optimizer.zero_grad()

            output = model(inputs)

            if isinstance(output, tuple):
                if isinstance(output[1], torch.Tensor):
                    logits = output[1]
                else:
                    raise TypeError(f"[ERROR] Expected Tensor in tuple[1], got {type(output[1])}")
            elif isinstance(output, dict):
                logits = output.get("logits") or output.get("out") or next(iter(output.values()))
            else:
                logits = output

            if not isinstance(logits, torch.Tensor):
                raise TypeError(f"[ERROR] Expected Tensor for logits, got {type(logits)}")




            loss = loss_fn(logits, targets)
            # print(loss.item())
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            # print(train_loss)
        # print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_loss/len(train_imgs):.4f}")
        
        model.eval()
        val_loss = 0.0
        val_miou = 0.0
        with torch.no_grad():
            for img, mask in zip(val_imgs, val_masks):
                inputs = torch.tensor(img, device=device).float().unsqueeze(0)
                targets = torch.tensor(mask+1, device=device).long().unsqueeze(0)
                output = model(inputs)

                if isinstance(output, tuple):
                    if isinstance(output[1], torch.Tensor):
                        logits = output[1]
                    else:
                        raise TypeError(f"[ERROR] Expected Tensor in tuple[1], got {type(output[1])}")
                elif isinstance(output, dict):
                    logits = output.get("logits") or output.get("out") or next(iter(output.values()))
                else:
                    logits = output

                # Final check
                if not isinstance(logits, torch.Tensor):
                    raise TypeError(f"[ERROR] Expected Tensor for logits, got {type(logits)}")



                loss = loss_fn(logits, targets)
                val_loss += loss.item()
                preds = torch.argmax(logits, dim=1)  
                
                val_miou += compute_iou(preds.cpu(), targets.cpu())
        val_miou /= len(val_imgs)
        miou_history.append(val_miou)
        
        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_loss/len(train_imgs):.4f} | "
              f"Val Loss: {val_loss/len(val_imgs):.4f} | Val mIoU: {val_miou:.4f}")
        
        # Save best model
        if val_miou > best_miou:
            best_miou = val_miou
            torch.save(model.state_dict(), "best_model.pth")
            print(f"  Saved new best model with mIoU {best_miou:.4f}")
    
    return model, miou_history

# %%
from terratorch.registry import FULL_MODEL_REGISTRY
import torch.nn as nn
import torch
def compute_iou(output, target):
    output = output.flatten()
    target = target.flatten()
    
    mask = (target == 1) | (target == 2)
    
    output_filtered = output[mask]
    target_filtered = target[mask]
    
    intersection = torch.sum(output_filtered == target_filtered)
    union = output_filtered.numel()  
    
    return (intersection + 1e-7) / (union + 1e-7)
backbone = FULL_MODEL_REGISTRY.build(
    "prithvi_eo_v2_300_mae",  
    pretrained=True,
    checkpoint_path=None  
)

class CNNHead(nn.Module):
    def __init__(self, in_channels=6):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Conv2d(6, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.Conv2d(64, 3, kernel_size=1)
        )
        
    def forward(self, x):
        return self.layers(x)

class PrithviWithCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = backbone
        self.head = CNNHead(in_channels=6) 
        
    def forward(self, x):
        features = self.backbone(x)[1]  
        return self.head(features)

# Test
model = PrithviWithCNN()
x = torch.rand(1, 6, 512, 512)  
output = model(x)
print(output.shape)
# Out:
# INFO:terratorch.models.backbones.prithvi_vit:model_bands not passed. Assuming bands are ordered in the same way as [<HLSBands.BLUE: 'BLUE'>, <HLSBands.GREEN: 'GREEN'>, <HLSBands.RED: 'RED'>, <HLSBands.NIR_NARROW: 'NIR_NARROW'>, <HLSBands.SWIR_1: 'SWIR_1'>, <HLSBands.SWIR_2: 'SWIR_2'>].Pretrained patch_embed layer may be misaligned with current bands
# INFO:root:Loaded weights for HLSBands.BLUE in position 0 of patch embed
# INFO:root:Loaded weights for HLSBands.GREEN in position 1 of patch embed
# INFO:root:Loaded weights for HLSBands.RED in position 2 of patch embed
# INFO:root:Loaded weights for HLSBands.NIR_NARROW in position 3 of patch embed
# INFO:root:Loaded weights for HLSBands.SWIR_1 in position 4 of patch embed
# INFO:root:Loaded weights for HLSBands.SWIR_2 in position 5 of patch embed
# torch.Size([1, 3, 512, 512])

# %%
def train_model(
    train_imgs, train_masks, 
    val_imgs, val_masks, 
    test_imgs, test_masks,  # NEW: test data
    model_class, 
    num_classes=3, 
    epochs=100, 
    lr=1e-3, 
    loss_fn=None, 
    optimizer_class=None,
    device=None
):
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = PrithviWithCNN().to(device)
    for param in model.backbone.parameters():
        param.requires_grad = False
    if loss_fn is None:
        loss_fn = nn.CrossEntropyLoss(ignore_index=-1)
    if optimizer_class is None:
        optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
    else:
        optimizer = optimizer_class(model.parameters(), lr=lr)
    
    miou_history = []
    best_miou = 0.0
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        for img, mask in zip(train_imgs, train_masks):
            inputs = torch.tensor(img, device=device).float().unsqueeze(0)
            targets = torch.tensor(mask+1, device=device).long().unsqueeze(0)
            optimizer.zero_grad()
            logits = model(inputs)
            preds = torch.argmax(logits, dim=1)
            probs = torch.nn.functional.softmax(logits, dim=1)
            preds = probs.argmax(dim=1)  # Shape: [B, H, W]
            unique_classes = torch.unique(preds)

            loss = loss_fn(logits, targets)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        model.eval()
        val_loss = 0.0
        val_miou = 0.0
        with torch.no_grad():
            for img, mask in zip(val_imgs, val_masks):
                inputs = torch.tensor(img, device=device).float().unsqueeze(0)
                targets = torch.tensor(mask+1, device=device).long().unsqueeze(0)
                logits = model(inputs)
                loss = loss_fn(logits, targets)
                val_loss += loss.item()
                preds = torch.argmax(logits, dim=1)
                val_miou += compute_iou(preds.cpu(), targets.cpu())

        val_miou /= len(val_imgs)
        miou_history.append(val_miou)

        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_loss/len(train_imgs):.4f} | "
              f"Val Loss: {val_loss/len(val_imgs):.4f} | Val mIoU: {val_miou:.4f}")
        
        if val_miou > best_miou:
            best_miou = val_miou
            torch.save(model.state_dict(), "best_model.pth")
            print(f"  Saved new best model with mIoU {best_miou:.4f}")
        # if epoch == 5:
        #     for param in model.backbone.parameters()[-2:]:  # Unfreeze last 2 layers
        #         param.requires_grad = True

    # After training, evaluate on test set
    test_miou = 0.0
    with torch.no_grad():
        for img, mask in zip(test_imgs, test_masks):
            inputs = torch.tensor(img, device=device).float().unsqueeze(0)
            targets = torch.tensor(mask+1, device=device).long().unsqueeze(0)
            logits = model(inputs)
            preds = torch.argmax(logits, dim=1)
            test_miou += compute_iou(preds.cpu(), targets.cpu())

    test_miou /= len(test_imgs)
    print(f"\n✅ Final Test mIoU: {test_miou:.4f}")

    return model, miou_history, test_miou

# %%
from tabulate import tabulate

def run_sensitivity_analysis(full_train_data, full_train_masks, val_data, val_masks, test_data, test_masks):
    data_fractions = [1.0, 0.5, 0.25, 0.1]
    histories = []
    test_mious = []

    for frac in data_fractions:
        n_samples = int(len(full_train_data) * frac)
        train_subset = full_train_data[:n_samples]
        mask_subset = full_train_masks[:n_samples]
        
        print(f"\n🔍 Training with {frac*100:.0f}% of data ({n_samples} samples)...")
        
        model, history, test_miou = train_model(
            train_subset, mask_subset,
            val_data, val_masks,
            test_data, test_masks,
            model_class=PrithviWithCNN()
        )
        
        histories.append((f"{frac*100}% Data", history))
        test_mious.append(test_miou)
    
    plot_sensitivity([h[1] for h in histories], [h[0] for h in histories])

    # Pretty print test mIoUs
    table = [(label, f"{miou:.4f}") for label, miou in zip([h[0] for h in histories], test_mious)]
    print("\n📊 Final Test mIoU Summary:")
    print(tabulate(table, headers=["Training Data Used", "Test mIoU"], tablefmt="fancy_grid"))
run_sensitivity_analysis(train_img, train_mask, val_img, val_mask,test_img, test_mask)
# Out:
# 🔍 Training with 100% of data (252 samples)...
# Epoch 1/100 | Train Loss: 0.7293 | Val Loss: 0.9115 | Val mIoU: 0.8792
#   Saved new best model with mIoU 0.8792
# Epoch 2/100 | Train Loss: 0.5591 | Val Loss: 0.4955 | Val mIoU: 0.8898
#   Saved new best model with mIoU 0.8898
# Epoch 3/100 | Train Loss: 0.5461 | Val Loss: 0.4619 | Val mIoU: 0.8904
#   Saved new best model with mIoU 0.8904
# Epoch 4/100 | Train Loss: 0.5378 | Val Loss: 0.4399 | Val mIoU: 0.8980
#   Saved new best model with mIoU 0.8980
# Epoch 5/100 | Train Loss: 0.5264 | Val Loss: 0.4751 | Val mIoU: 0.8926
# Epoch 6/100 | Train Loss: 0.5186 | Val Loss: 0.4545 | Val mIoU: 0.9117
#   Saved new best model with mIoU 0.9117
# Epoch 7/100 | Train Loss: 0.5103 | Val Loss: 0.4417 | Val mIoU: 0.8988
# Epoch 8/100 | Train Loss: 0.5082 | Val Loss: 0.4609 | Val mIoU: 0.9062
# Epoch 9/100 | Train Loss: 0.5005 | Val Loss: 0.4370 | Val mIoU: 0.8797
# Epoch 10/100 | Train Loss: 0.4978 | Val Loss: 0.4312 | Val mIoU: 0.8893
# Epoch 11/100 | Train Loss: 0.4884 | Val Loss: 0.4297 | Val mIoU: 0.8801
# Epoch 12/100 | Train Loss: 0.4860 | Val Loss: 0.4395 | Val mIoU: 0.8750
# Epoch 13/100 | Train Loss: 0.4844 | Val Loss: 0.4431 | Val mIoU: 0.8796
# Epoch 14/100 | Train Loss: 0.4742 | Val Loss: 0.4305 | Val mIoU: 0.8721
# Epoch 15/100 | Train Loss: 0.4767 | Val Loss: 0.4294 | Val mIoU: 0.8603
# Epoch 16/100 | Train Loss: 0.4727 | Val Loss: 0.4159 | Val mIoU: 0.8732
# Epoch 17/100 | Train Loss: 0.4734 | Val Loss: 0.4684 | Val mIoU: 0.8561
# Epoch 18/100 | Train Loss: 0.4758 | Val Loss: 0.4490 | Val mIoU: 0.8590
# Epoch 19/100 | Train Loss: 0.4688 | Val Loss: 0.4216 | Val mIoU: 0.8660
# Epoch 20/100 | Train Loss: 0.4587 | Val Loss: 0.4249 | Val mIoU: 0.8645
# Epoch 21/100 | Train Loss: 0.4558 | Val Loss: 0.4333 | Val mIoU: 0.8457
# Epoch 22/100 | Train Loss: 0.4545 | Val Loss: 0.4411 | Val mIoU: 0.8343
# Epoch 23/100 | Train Loss: 0.4539 | Val Loss: 0.4618 | Val mIoU: 0.8554
# Epoch 24/100 | Train Loss: 0.4476 | Val Loss: 0.4384 | Val mIoU: 0.8564
# Epoch 25/100 | Train Loss: 0.4384 | Val Loss: 0.4394 | Val mIoU: 0.8484
# Epoch 26/100 | Train Loss: 0.4444 | Val Loss: 0.4669 | Val mIoU: 0.8372
# Epoch 27/100 | Train Loss: 0.4419 | Val Loss: 0.4444 | Val mIoU: 0.8523
# Epoch 28/100 | Train Loss: 0.4380 | Val Loss: 0.4642 | Val mIoU: 0.8392
# Epoch 29/100 | Train Loss: 0.4363 | Val Loss: 0.4682 | Val mIoU: 0.8448
# Epoch 30/100 | Train Loss: 0.4340 | Val Loss: 0.4737 | Val mIoU: 0.8264
# Epoch 31/100 | Train Loss: 0.4284 | Val Loss: 0.4515 | Val mIoU: 0.8423
# Epoch 32/100 | Train Loss: 0.4328 | Val Loss: 0.4787 | Val mIoU: 0.8334
# Epoch 33/100 | Train Loss: 0.4260 | Val Loss: 0.4568 | Val mIoU: 0.8735
# Epoch 34/100 | Train Loss: 0.4302 | Val Loss: 0.4408 | Val mIoU: 0.8577
# Epoch 35/100 | Train Loss: 0.4292 | Val Loss: 0.4754 | Val mIoU: 0.8278
# Epoch 36/100 | Train Loss: 0.4207 | Val Loss: 0.4627 | Val mIoU: 0.8504
# Epoch 37/100 | Train Loss: 0.4238 | Val Loss: 0.4640 | Val mIoU: 0.8309
# Epoch 38/100 | Train Loss: 0.4208 | Val Loss: 0.4669 | Val mIoU: 0.8473
# Epoch 39/100 | Train Loss: 0.4203 | Val Loss: 0.4531 | Val mIoU: 0.8490
# Epoch 40/100 | Train Loss: 0.4158 | Val Loss: 0.4449 | Val mIoU: 0.8607
# Epoch 41/100 | Train Loss: 0.4081 | Val Loss: 0.4674 | Val mIoU: 0.8570
# Epoch 42/100 | Train Loss: 0.4107 | Val Loss: 0.4914 | Val mIoU: 0.8306
# Epoch 43/100 | Train Loss: 0.4084 | Val Loss: 0.4829 | Val mIoU: 0.8265
# Epoch 44/100 | Train Loss: 0.4048 | Val Loss: 0.4729 | Val mIoU: 0.8462
# Epoch 45/100 | Train Loss: 0.4020 | Val Loss: 0.4907 | Val mIoU: 0.8421
# Epoch 46/100 | Train Loss: 0.4034 | Val Loss: 0.4740 | Val mIoU: 0.8387
# Epoch 47/100 | Train Loss: 0.3973 | Val Loss: 0.4698 | Val mIoU: 0.8359
# Epoch 48/100 | Train Loss: 0.3981 | Val Loss: 0.5197 | Val mIoU: 0.8153
# Epoch 49/100 | Train Loss: 0.3978 | Val Loss: 0.4488 | Val mIoU: 0.8504
# Epoch 50/100 | Train Loss: 0.3934 | Val Loss: 0.4755 | Val mIoU: 0.8591
# Epoch 51/100 | Train Loss: 0.3954 | Val Loss: 0.4770 | Val mIoU: 0.8333
# Epoch 52/100 | Train Loss: 0.3971 | Val Loss: 0.5700 | Val mIoU: 0.7945
# Epoch 53/100 | Train Loss: 0.3899 | Val Loss: 0.4767 | Val mIoU: 0.8367
# Epoch 54/100 | Train Loss: 0.3863 | Val Loss: 0.5082 | Val mIoU: 0.8295
# Epoch 55/100 | Train Loss: 0.3846 | Val Loss: 0.5276 | Val mIoU: 0.8411
# Epoch 56/100 | Train Loss: 0.3897 | Val Loss: 0.4457 | Val mIoU: 0.8679
# Epoch 57/100 | Train Loss: 0.3794 | Val Loss: 0.4458 | Val mIoU: 0.8726
# Epoch 58/100 | Train Loss: 0.3844 | Val Loss: 0.4592 | Val mIoU: 0.8439
# Epoch 59/100 | Train Loss: 0.3821 | Val Loss: 0.4518 | Val mIoU: 0.8633
# Epoch 60/100 | Train Loss: 0.3828 | Val Loss: 0.4512 | Val mIoU: 0.8569
# Epoch 61/100 | Train Loss: 0.3826 | Val Loss: 0.4789 | Val mIoU: 0.8576
# Epoch 62/100 | Train Loss: 0.3786 | Val Loss: 0.4584 | Val mIoU: 0.8711
# Epoch 63/100 | Train Loss: 0.3793 | Val Loss: 0.4213 | Val mIoU: 0.8893
# Epoch 64/100 | Train Loss: 0.3757 | Val Loss: 0.4720 | Val mIoU: 0.8843
# Epoch 65/100 | Train Loss: 0.3741 | Val Loss: 0.4548 | Val mIoU: 0.8941
# Epoch 66/100 | Train Loss: 0.3775 | Val Loss: 0.5073 | Val mIoU: 0.8584
# Epoch 67/100 | Train Loss: 0.3710 | Val Loss: 0.4883 | Val mIoU: 0.8760
# Epoch 68/100 | Train Loss: 0.3737 | Val Loss: 0.4564 | Val mIoU: 0.8807
# Epoch 69/100 | Train Loss: 0.3691 | Val Loss: 0.5938 | Val mIoU: 0.8879
# Epoch 70/100 | Train Loss: 0.3712 | Val Loss: 0.4393 | Val mIoU: 0.8958
# Epoch 71/100 | Train Loss: 0.3672 | Val Loss: 0.4854 | Val mIoU: 0.8858
# Epoch 72/100 | Train Loss: 0.3673 | Val Loss: 0.4783 | Val mIoU: 0.8914
# Epoch 73/100 | Train Loss: 0.3696 | Val Loss: 0.4597 | Val mIoU: 0.8805
# Epoch 74/100 | Train Loss: 0.3725 | Val Loss: 0.5152 | Val mIoU: 0.8985
# Epoch 75/100 | Train Loss: 0.3700 | Val Loss: 0.4722 | Val mIoU: 0.8728
# Epoch 76/100 | Train Loss: 0.3682 | Val Loss: 0.4557 | Val mIoU: 0.8909
# Epoch 77/100 | Train Loss: 0.3559 | Val Loss: 0.4973 | Val mIoU: 0.8798
# Epoch 78/100 | Train Loss: 0.3663 | Val Loss: 0.4800 | Val mIoU: 0.8918
# Epoch 79/100 | Train Loss: 0.3601 | Val Loss: 0.5360 | Val mIoU: 0.8973
# Epoch 80/100 | Train Loss: 0.3596 | Val Loss: 0.4843 | Val mIoU: 0.9049
# Epoch 81/100 | Train Loss: 0.3603 | Val Loss: 0.5486 | Val mIoU: 0.9064
# Epoch 82/100 | Train Loss: 0.3572 | Val Loss: 0.5428 | Val mIoU: 0.8856
# Epoch 83/100 | Train Loss: 0.3561 | Val Loss: 0.5995 | Val mIoU: 0.8849
# Epoch 84/100 | Train Loss: 0.3722 | Val Loss: 0.5938 | Val mIoU: 0.8700
# Epoch 85/100 | Train Loss: 0.3718 | Val Loss: 0.5742 | Val mIoU: 0.8952
# Epoch 86/100 | Train Loss: 0.3618 | Val Loss: 0.4634 | Val mIoU: 0.8996
# Epoch 87/100 | Train Loss: 0.3539 | Val Loss: 0.5227 | Val mIoU: 0.9016
# Epoch 88/100 | Train Loss: 0.3550 | Val Loss: 0.5206 | Val mIoU: 0.8956
# Epoch 89/100 | Train Loss: 0.3532 | Val Loss: 0.6258 | Val mIoU: 0.9042
# Epoch 90/100 | Train Loss: 0.3530 | Val Loss: 0.5698 | Val mIoU: 0.8856
# Epoch 91/100 | Train Loss: 0.3521 | Val Loss: 0.5473 | Val mIoU: 0.8863
# Epoch 92/100 | Train Loss: 0.3424 | Val Loss: 0.5728 | Val mIoU: 0.8899
# Epoch 93/100 | Train Loss: 0.3648 | Val Loss: 0.6805 | Val mIoU: 0.8943
# Epoch 94/100 | Train Loss: 0.3515 | Val Loss: 0.6693 | Val mIoU: 0.9075
# Epoch 95/100 | Train Loss: 0.3475 | Val Loss: 0.6990 | Val mIoU: 0.8917
# Epoch 96/100 | Train Loss: 0.3540 | Val Loss: 0.4868 | Val mIoU: 0.8980
# Epoch 97/100 | Train Loss: 0.3501 | Val Loss: 0.5551 | Val mIoU: 0.9041
# Epoch 98/100 | Train Loss: 0.3517 | Val Loss: 0.6133 | Val mIoU: 0.8853
# Epoch 99/100 | Train Loss: 0.3460 | Val Loss: 0.5909 | Val mIoU: 0.8900
# Epoch 100/100 | Train Loss: 0.3447 | Val Loss: 0.6100 | Val mIoU: 0.9048
#
# ✅ Final Test mIoU: 0.9044
#
# 🔍 Training with 50% of data (126 samples)...
# Epoch 1/100 | Train Loss: 0.9134 | Val Loss: 0.5830 | Val mIoU: 0.8328
#   Saved new best model with mIoU 0.8328
# Epoch 2/100 | Train Loss: 0.7150 | Val Loss: 0.4758 | Val mIoU: 0.9176
#   Saved new best model with mIoU 0.9176
# Epoch 3/100 | Train Loss: 0.6712 | Val Loss: 0.4511 | Val mIoU: 0.9161
# Epoch 4/100 | Train Loss: 0.6585 | Val Loss: 0.4218 | Val mIoU: 0.9004
# Epoch 5/100 | Train Loss: 0.6448 | Val Loss: 0.4485 | Val mIoU: 0.9262
#   Saved new best model with mIoU 0.9262
# Epoch 6/100 | Train Loss: 0.6329 | Val Loss: 0.5016 | Val mIoU: 0.9228
# Epoch 7/100 | Train Loss: 0.6289 | Val Loss: 0.4253 | Val mIoU: 0.9284
#   Saved new best model with mIoU 0.9284
# Epoch 8/100 | Train Loss: 0.6239 | Val Loss: 0.4852 | Val mIoU: 0.9316
#   Saved new best model with mIoU 0.9316
# Epoch 9/100 | Train Loss: 0.6120 | Val Loss: 0.6228 | Val mIoU: 0.9305
# Epoch 10/100 | Train Loss: 0.6119 | Val Loss: 0.5057 | Val mIoU: 0.9286
# Epoch 11/100 | Train Loss: 0.6117 | Val Loss: 0.4959 | Val mIoU: 0.9280
# Epoch 12/100 | Train Loss: 0.6043 | Val Loss: 0.6726 | Val mIoU: 0.9309
# Epoch 13/100 | Train Loss: 0.6002 | Val Loss: 0.6278 | Val mIoU: 0.9267
# Epoch 14/100 | Train Loss: 0.5993 | Val Loss: 0.5687 | Val mIoU: 0.9225
# Epoch 15/100 | Train Loss: 0.5931 | Val Loss: 0.7229 | Val mIoU: 0.9335
#   Saved new best model with mIoU 0.9335
# Epoch 16/100 | Train Loss: 0.5878 | Val Loss: 0.4499 | Val mIoU: 0.9221
# Epoch 17/100 | Train Loss: 0.5818 | Val Loss: 0.4362 | Val mIoU: 0.9225
# Epoch 18/100 | Train Loss: 0.5892 | Val Loss: 0.5312 | Val mIoU: 0.9249
# Epoch 19/100 | Train Loss: 0.5749 | Val Loss: 0.5151 | Val mIoU: 0.9202
# Epoch 20/100 | Train Loss: 0.5734 | Val Loss: 0.4350 | Val mIoU: 0.9190
# Epoch 21/100 | Train Loss: 0.5758 | Val Loss: 0.9295 | Val mIoU: 0.9230
# Epoch 22/100 | Train Loss: 0.5692 | Val Loss: 0.8268 | Val mIoU: 0.9231
# Epoch 23/100 | Train Loss: 0.5694 | Val Loss: 0.4674 | Val mIoU: 0.9078
# Epoch 24/100 | Train Loss: 0.5665 | Val Loss: 0.8604 | Val mIoU: 0.9277
# Epoch 25/100 | Train Loss: 0.5649 | Val Loss: 0.6921 | Val mIoU: 0.9252
# Epoch 26/100 | Train Loss: 0.5654 | Val Loss: 0.4560 | Val mIoU: 0.8931
# Epoch 27/100 | Train Loss: 0.5572 | Val Loss: 0.5189 | Val mIoU: 0.9098
# Epoch 28/100 | Train Loss: 0.5564 | Val Loss: 0.9372 | Val mIoU: 0.9194
# Epoch 29/100 | Train Loss: 0.5586 | Val Loss: 0.9557 | Val mIoU: 0.9209
# Epoch 30/100 | Train Loss: 0.5557 | Val Loss: 0.5670 | Val mIoU: 0.8972
# Epoch 31/100 | Train Loss: 0.5516 | Val Loss: 0.5437 | Val mIoU: 0.9061
# Epoch 32/100 | Train Loss: 0.5549 | Val Loss: 0.6316 | Val mIoU: 0.9090
# Epoch 33/100 | Train Loss: 0.5400 | Val Loss: 0.5986 | Val mIoU: 0.9029
# Epoch 34/100 | Train Loss: 0.5363 | Val Loss: 0.8453 | Val mIoU: 0.9136
# Epoch 35/100 | Train Loss: 0.5400 | Val Loss: 0.9282 | Val mIoU: 0.8878
# Epoch 36/100 | Train Loss: 0.5369 | Val Loss: 0.5744 | Val mIoU: 0.9121
# Epoch 37/100 | Train Loss: 0.5384 | Val Loss: 0.9555 | Val mIoU: 0.9102
# Epoch 38/100 | Train Loss: 0.5312 | Val Loss: 0.7373 | Val mIoU: 0.9158
# Epoch 39/100 | Train Loss: 0.5263 | Val Loss: 0.7769 | Val mIoU: 0.8991
# Epoch 40/100 | Train Loss: 0.5292 | Val Loss: 0.7458 | Val mIoU: 0.9035
# Epoch 41/100 | Train Loss: 0.5268 | Val Loss: 0.9743 | Val mIoU: 0.9010
# Epoch 42/100 | Train Loss: 0.5235 | Val Loss: 0.5950 | Val mIoU: 0.9063
# Epoch 43/100 | Train Loss: 0.5247 | Val Loss: 0.7245 | Val mIoU: 0.8966
# Epoch 44/100 | Train Loss: 0.5254 | Val Loss: 0.6936 | Val mIoU: 0.9095
# Epoch 45/100 | Train Loss: 0.5074 | Val Loss: 0.9356 | Val mIoU: 0.8854
# Epoch 46/100 | Train Loss: 0.5087 | Val Loss: 1.0480 | Val mIoU: 0.9160
# Epoch 47/100 | Train Loss: 0.5180 | Val Loss: 0.6203 | Val mIoU: 0.8971
# Epoch 48/100 | Train Loss: 0.5253 | Val Loss: 0.5923 | Val mIoU: 0.8949
# Epoch 49/100 | Train Loss: 0.5106 | Val Loss: 0.6766 | Val mIoU: 0.9038
# Epoch 50/100 | Train Loss: 0.5060 | Val Loss: 0.7164 | Val mIoU: 0.9019
# Epoch 51/100 | Train Loss: 0.5111 | Val Loss: 1.0111 | Val mIoU: 0.9045
# Epoch 52/100 | Train Loss: 0.5078 | Val Loss: 0.7182 | Val mIoU: 0.8927
# Epoch 53/100 | Train Loss: 0.5060 | Val Loss: 0.8626 | Val mIoU: 0.8923
# Epoch 54/100 | Train Loss: 0.5014 | Val Loss: 0.7857 | Val mIoU: 0.9017
# Epoch 55/100 | Train Loss: 0.4950 | Val Loss: 1.0215 | Val mIoU: 0.9037
# Epoch 56/100 | Train Loss: 0.5021 | Val Loss: 0.7628 | Val mIoU: 0.8923
# Epoch 57/100 | Train Loss: 0.5094 | Val Loss: 0.8400 | Val mIoU: 0.8860
# Epoch 58/100 | Train Loss: 0.5007 | Val Loss: 0.7230 | Val mIoU: 0.9006
# Epoch 59/100 | Train Loss: 0.5076 | Val Loss: 0.7012 | Val mIoU: 0.8875
# Epoch 60/100 | Train Loss: 0.5184 | Val Loss: 0.6828 | Val mIoU: 0.8991
# Epoch 61/100 | Train Loss: 0.5186 | Val Loss: 0.6043 | Val mIoU: 0.8999
# Epoch 62/100 | Train Loss: 0.5055 | Val Loss: 0.7418 | Val mIoU: 0.9117
# Epoch 63/100 | Train Loss: 0.4976 | Val Loss: 0.7544 | Val mIoU: 0.9047
# Epoch 64/100 | Train Loss: 0.4861 | Val Loss: 0.8665 | Val mIoU: 0.9016
# Epoch 65/100 | Train Loss: 0.4927 | Val Loss: 0.8343 | Val mIoU: 0.9068
# Epoch 66/100 | Train Loss: 0.4840 | Val Loss: 0.8923 | Val mIoU: 0.8928
# Epoch 67/100 | Train Loss: 0.4767 | Val Loss: 0.8255 | Val mIoU: 0.9069
# Epoch 68/100 | Train Loss: 0.4865 | Val Loss: 0.8471 | Val mIoU: 0.8904
# Epoch 69/100 | Train Loss: 0.4751 | Val Loss: 0.8230 | Val mIoU: 0.8955
# Epoch 70/100 | Train Loss: 0.4762 | Val Loss: 0.9584 | Val mIoU: 0.8956
# Epoch 71/100 | Train Loss: 0.4842 | Val Loss: 0.7652 | Val mIoU: 0.8996
# Epoch 72/100 | Train Loss: 0.4859 | Val Loss: 1.0756 | Val mIoU: 0.8917
# Epoch 73/100 | Train Loss: 0.4798 | Val Loss: 0.6362 | Val mIoU: 0.8932
# Epoch 74/100 | Train Loss: 0.4726 | Val Loss: 0.5721 | Val mIoU: 0.8877
# Epoch 75/100 | Train Loss: 0.4801 | Val Loss: 0.7737 | Val mIoU: 0.9105
# Epoch 76/100 | Train Loss: 0.4732 | Val Loss: 0.7572 | Val mIoU: 0.9028
# Epoch 77/100 | Train Loss: 0.4682 | Val Loss: 0.7219 | Val mIoU: 0.8940
# Epoch 78/100 | Train Loss: 0.4681 | Val Loss: 0.7352 | Val mIoU: 0.8837
# Epoch 79/100 | Train Loss: 0.4825 | Val Loss: 1.1559 | Val mIoU: 0.8986
# Epoch 80/100 | Train Loss: 0.4745 | Val Loss: 0.7774 | Val mIoU: 0.8857
# Epoch 81/100 | Train Loss: 0.4629 | Val Loss: 0.8738 | Val mIoU: 0.8845
# Epoch 82/100 | Train Loss: 0.4643 | Val Loss: 0.6556 | Val mIoU: 0.8578
# Epoch 83/100 | Train Loss: 0.5050 | Val Loss: 0.6559 | Val mIoU: 0.9035
# Epoch 84/100 | Train Loss: 0.4731 | Val Loss: 1.0250 | Val mIoU: 0.8970
# Epoch 85/100 | Train Loss: 0.4696 | Val Loss: 0.8075 | Val mIoU: 0.8985
# Epoch 86/100 | Train Loss: 0.4709 | Val Loss: 0.9553 | Val mIoU: 0.8719
# Epoch 87/100 | Train Loss: 0.4668 | Val Loss: 0.6986 | Val mIoU: 0.8875
# Epoch 88/100 | Train Loss: 0.4726 | Val Loss: 0.9991 | Val mIoU: 0.8854
# Epoch 89/100 | Train Loss: 0.4566 | Val Loss: 0.5959 | Val mIoU: 0.8902
# Epoch 90/100 | Train Loss: 0.4580 | Val Loss: 0.7328 | Val mIoU: 0.8856
# Epoch 91/100 | Train Loss: 0.4547 | Val Loss: 0.8089 | Val mIoU: 0.8924
# Epoch 92/100 | Train Loss: 0.4546 | Val Loss: 0.9981 | Val mIoU: 0.8915
# Epoch 93/100 | Train Loss: 0.4649 | Val Loss: 0.6015 | Val mIoU: 0.8783
# Epoch 94/100 | Train Loss: 0.4546 | Val Loss: 1.0285 | Val mIoU: 0.8980
# Epoch 95/100 | Train Loss: 0.4559 | Val Loss: 0.9608 | Val mIoU: 0.8863
# Epoch 96/100 | Train Loss: 0.4521 | Val Loss: 0.8262 | Val mIoU: 0.8879
# Epoch 97/100 | Train Loss: 0.4642 | Val Loss: 0.6725 | Val mIoU: 0.8848
# Epoch 98/100 | Train Loss: 0.4527 | Val Loss: 0.6750 | Val mIoU: 0.8807
# Epoch 99/100 | Train Loss: 0.4541 | Val Loss: 1.1974 | Val mIoU: 0.8929
# Epoch 100/100 | Train Loss: 0.4566 | Val Loss: 0.7865 | Val mIoU: 0.8852
#
# ✅ Final Test mIoU: 0.8680
#
# 🔍 Training with 25% of data (63 samples)...
# Epoch 1/100 | Train Loss: 1.0360 | Val Loss: 1.0453 | Val mIoU: 0.6615
#   Saved new best model with mIoU 0.6615
# Epoch 2/100 | Train Loss: 0.8957 | Val Loss: 0.6916 | Val mIoU: 0.7573
#   Saved new best model with mIoU 0.7573
# Epoch 3/100 | Train Loss: 0.7552 | Val Loss: 0.5616 | Val mIoU: 0.8133
#   Saved new best model with mIoU 0.8133
# Epoch 4/100 | Train Loss: 0.6815 | Val Loss: 0.4919 | Val mIoU: 0.8561
#   Saved new best model with mIoU 0.8561
# Epoch 5/100 | Train Loss: 0.6658 | Val Loss: 0.5138 | Val mIoU: 0.8558
# Epoch 6/100 | Train Loss: 0.6493 | Val Loss: 0.5206 | Val mIoU: 0.8277
# Epoch 7/100 | Train Loss: 0.6407 | Val Loss: 0.4603 | Val mIoU: 0.8702
#   Saved new best model with mIoU 0.8702
# Epoch 8/100 | Train Loss: 0.6325 | Val Loss: 0.5234 | Val mIoU: 0.8120
# Epoch 9/100 | Train Loss: 0.6269 | Val Loss: 0.4532 | Val mIoU: 0.8638
# Epoch 10/100 | Train Loss: 0.6254 | Val Loss: 0.4756 | Val mIoU: 0.8676
# Epoch 11/100 | Train Loss: 0.6213 | Val Loss: 0.4323 | Val mIoU: 0.8875
#   Saved new best model with mIoU 0.8875
# Epoch 12/100 | Train Loss: 0.6184 | Val Loss: 0.4931 | Val mIoU: 0.8239
# Epoch 13/100 | Train Loss: 0.6182 | Val Loss: 0.4581 | Val mIoU: 0.8458
# Epoch 14/100 | Train Loss: 0.6162 | Val Loss: 0.5701 | Val mIoU: 0.7989
# Epoch 15/100 | Train Loss: 0.6141 | Val Loss: 0.4962 | Val mIoU: 0.8230
# Epoch 16/100 | Train Loss: 0.6223 | Val Loss: 0.4699 | Val mIoU: 0.8579
# Epoch 17/100 | Train Loss: 0.6112 | Val Loss: 0.4908 | Val mIoU: 0.8318
# Epoch 18/100 | Train Loss: 0.6095 | Val Loss: 0.6390 | Val mIoU: 0.7786
# Epoch 19/100 | Train Loss: 0.6311 | Val Loss: 0.5285 | Val mIoU: 0.7936
# Epoch 20/100 | Train Loss: 0.6075 | Val Loss: 0.5276 | Val mIoU: 0.8322
# Epoch 21/100 | Train Loss: 0.6105 | Val Loss: 0.5524 | Val mIoU: 0.8144
# Epoch 22/100 | Train Loss: 0.5981 | Val Loss: 0.4983 | Val mIoU: 0.8182
# Epoch 23/100 | Train Loss: 0.6018 | Val Loss: 0.5090 | Val mIoU: 0.8373
# Epoch 24/100 | Train Loss: 0.5931 | Val Loss: 0.5714 | Val mIoU: 0.8047
# Epoch 25/100 | Train Loss: 0.6049 | Val Loss: 0.4826 | Val mIoU: 0.8398
# Epoch 26/100 | Train Loss: 0.5924 | Val Loss: 0.5588 | Val mIoU: 0.7892
# Epoch 27/100 | Train Loss: 0.5926 | Val Loss: 0.5809 | Val mIoU: 0.7876
# Epoch 28/100 | Train Loss: 0.5923 | Val Loss: 0.6596 | Val mIoU: 0.7572
# Epoch 29/100 | Train Loss: 0.5955 | Val Loss: 0.4973 | Val mIoU: 0.8038
# Epoch 30/100 | Train Loss: 0.5902 | Val Loss: 0.4905 | Val mIoU: 0.8272
# Epoch 31/100 | Train Loss: 0.5794 | Val Loss: 0.6859 | Val mIoU: 0.7289
# Epoch 32/100 | Train Loss: 0.5729 | Val Loss: 0.6031 | Val mIoU: 0.7791
# Epoch 33/100 | Train Loss: 0.5700 | Val Loss: 0.5116 | Val mIoU: 0.8203
# Epoch 34/100 | Train Loss: 0.5700 | Val Loss: 0.6030 | Val mIoU: 0.7856
# Epoch 35/100 | Train Loss: 0.5796 | Val Loss: 0.5247 | Val mIoU: 0.7972
# Epoch 36/100 | Train Loss: 0.5644 | Val Loss: 0.5404 | Val mIoU: 0.8112
# Epoch 37/100 | Train Loss: 0.5529 | Val Loss: 0.5418 | Val mIoU: 0.7712
# Epoch 38/100 | Train Loss: 0.5591 | Val Loss: 0.6081 | Val mIoU: 0.7582
# Epoch 39/100 | Train Loss: 0.5554 | Val Loss: 0.6722 | Val mIoU: 0.7297
# Epoch 40/100 | Train Loss: 0.5532 | Val Loss: 0.5073 | Val mIoU: 0.8508
# Epoch 41/100 | Train Loss: 0.5555 | Val Loss: 0.5194 | Val mIoU: 0.8208
# Epoch 42/100 | Train Loss: 0.5791 | Val Loss: 0.5414 | Val mIoU: 0.8118
# Epoch 43/100 | Train Loss: 0.5638 | Val Loss: 0.4888 | Val mIoU: 0.8377
# Epoch 44/100 | Train Loss: 0.5500 | Val Loss: 0.4991 | Val mIoU: 0.8592
# Epoch 45/100 | Train Loss: 0.5672 | Val Loss: 0.5827 | Val mIoU: 0.7583
# Epoch 46/100 | Train Loss: 0.5495 | Val Loss: 0.5288 | Val mIoU: 0.7982
# Epoch 47/100 | Train Loss: 0.5347 | Val Loss: 0.5137 | Val mIoU: 0.8512
# Epoch 48/100 | Train Loss: 0.5508 | Val Loss: 0.4730 | Val mIoU: 0.8939
#   Saved new best model with mIoU 0.8939
# Epoch 49/100 | Train Loss: 0.5705 | Val Loss: 0.5644 | Val mIoU: 0.7931
# Epoch 50/100 | Train Loss: 0.5635 | Val Loss: 0.4700 | Val mIoU: 0.9080
#   Saved new best model with mIoU 0.9080
# Epoch 51/100 | Train Loss: 0.5872 | Val Loss: 0.5317 | Val mIoU: 0.8095
# Epoch 52/100 | Train Loss: 0.5587 | Val Loss: 0.5287 | Val mIoU: 0.8236
# Epoch 53/100 | Train Loss: 0.5566 | Val Loss: 0.5311 | Val mIoU: 0.8219
# Epoch 54/100 | Train Loss: 0.5260 | Val Loss: 0.5282 | Val mIoU: 0.7822
# Epoch 55/100 | Train Loss: 0.5327 | Val Loss: 0.5086 | Val mIoU: 0.8493
# Epoch 56/100 | Train Loss: 0.5274 | Val Loss: 0.4988 | Val mIoU: 0.8537
# Epoch 57/100 | Train Loss: 0.5306 | Val Loss: 0.5958 | Val mIoU: 0.8425
# Epoch 58/100 | Train Loss: 0.5591 | Val Loss: 0.5368 | Val mIoU: 0.8230
# Epoch 59/100 | Train Loss: 0.5464 | Val Loss: 0.6371 | Val mIoU: 0.7907
# Epoch 60/100 | Train Loss: 0.5296 | Val Loss: 0.5094 | Val mIoU: 0.8188
# Epoch 61/100 | Train Loss: 0.5267 | Val Loss: 0.5166 | Val mIoU: 0.8058
# Epoch 62/100 | Train Loss: 0.5312 | Val Loss: 0.5217 | Val mIoU: 0.8422
# Epoch 63/100 | Train Loss: 0.5338 | Val Loss: 0.4700 | Val mIoU: 0.8834
# Epoch 64/100 | Train Loss: 0.5213 | Val Loss: 0.4990 | Val mIoU: 0.8602
# Epoch 65/100 | Train Loss: 0.5531 | Val Loss: 0.6086 | Val mIoU: 0.7507
# Epoch 66/100 | Train Loss: 0.5212 | Val Loss: 0.5031 | Val mIoU: 0.8992
# Epoch 67/100 | Train Loss: 0.5390 | Val Loss: 0.5522 | Val mIoU: 0.8098
# Epoch 68/100 | Train Loss: 0.5314 | Val Loss: 0.5348 | Val mIoU: 0.7922
# Epoch 69/100 | Train Loss: 0.5123 | Val Loss: 0.5094 | Val mIoU: 0.8474
# Epoch 70/100 | Train Loss: 0.5132 | Val Loss: 0.5262 | Val mIoU: 0.8044
# Epoch 71/100 | Train Loss: 0.5130 | Val Loss: 0.4931 | Val mIoU: 0.8274
# Epoch 72/100 | Train Loss: 0.5030 | Val Loss: 0.4767 | Val mIoU: 0.8650
# Epoch 73/100 | Train Loss: 0.5119 | Val Loss: 0.4979 | Val mIoU: 0.8510
# Epoch 74/100 | Train Loss: 0.5141 | Val Loss: 0.5665 | Val mIoU: 0.7454
# Epoch 75/100 | Train Loss: 0.5100 | Val Loss: 0.5082 | Val mIoU: 0.8013
# Epoch 76/100 | Train Loss: 0.5073 | Val Loss: 0.5172 | Val mIoU: 0.8223
# Epoch 77/100 | Train Loss: 0.5035 | Val Loss: 0.5233 | Val mIoU: 0.8060
# Epoch 78/100 | Train Loss: 0.5089 | Val Loss: 0.5221 | Val mIoU: 0.8335
# Epoch 79/100 | Train Loss: 0.4897 | Val Loss: 0.5264 | Val mIoU: 0.8098
# Epoch 80/100 | Train Loss: 0.4973 | Val Loss: 0.5157 | Val mIoU: 0.8268
# Epoch 81/100 | Train Loss: 0.4967 | Val Loss: 0.5314 | Val mIoU: 0.8239
# Epoch 82/100 | Train Loss: 0.4926 | Val Loss: 0.5113 | Val mIoU: 0.8547
# Epoch 83/100 | Train Loss: 0.4876 | Val Loss: 0.5562 | Val mIoU: 0.7869
# Epoch 84/100 | Train Loss: 0.4935 | Val Loss: 0.5203 | Val mIoU: 0.8559
# Epoch 85/100 | Train Loss: 0.4954 | Val Loss: 0.5840 | Val mIoU: 0.7954
# Epoch 86/100 | Train Loss: 0.4928 | Val Loss: 0.5351 | Val mIoU: 0.8336
# Epoch 87/100 | Train Loss: 0.5066 | Val Loss: 0.5419 | Val mIoU: 0.8097
# Epoch 88/100 | Train Loss: 0.4971 | Val Loss: 0.5137 | Val mIoU: 0.8236
# Epoch 89/100 | Train Loss: 0.4789 | Val Loss: 0.5789 | Val mIoU: 0.8042
# Epoch 90/100 | Train Loss: 0.4736 | Val Loss: 0.5321 | Val mIoU: 0.8489
# Epoch 91/100 | Train Loss: 0.4804 | Val Loss: 0.5942 | Val mIoU: 0.7913
# Epoch 92/100 | Train Loss: 0.5136 | Val Loss: 0.5521 | Val mIoU: 0.8528
# Epoch 93/100 | Train Loss: 0.5003 | Val Loss: 0.5554 | Val mIoU: 0.8202
# Epoch 94/100 | Train Loss: 0.5231 | Val Loss: 0.4831 | Val mIoU: 0.8647
# Epoch 95/100 | Train Loss: 0.5207 | Val Loss: 0.6081 | Val mIoU: 0.7439
# Epoch 96/100 | Train Loss: 0.4911 | Val Loss: 0.5157 | Val mIoU: 0.8287
# Epoch 97/100 | Train Loss: 0.4876 | Val Loss: 0.5237 | Val mIoU: 0.8152
# Epoch 98/100 | Train Loss: 0.4783 | Val Loss: 0.6355 | Val mIoU: 0.7639
# Epoch 99/100 | Train Loss: 0.4874 | Val Loss: 0.5085 | Val mIoU: 0.8445
# Epoch 100/100 | Train Loss: 0.4764 | Val Loss: 0.5358 | Val mIoU: 0.8838
#
# ✅ Final Test mIoU: 0.8571
#
# 🔍 Training with 10% of data (25 samples)...
# Epoch 1/100 | Train Loss: 1.1110 | Val Loss: 0.9245 | Val mIoU: 0.7654
#   Saved new best model with mIoU 0.7654
# Epoch 2/100 | Train Loss: 1.0217 | Val Loss: 0.8865 | Val mIoU: 0.5541
# Epoch 3/100 | Train Loss: 0.9594 | Val Loss: 1.0861 | Val mIoU: 0.5587
# Epoch 4/100 | Train Loss: 0.8745 | Val Loss: 0.8805 | Val mIoU: 0.6595
# Epoch 5/100 | Train Loss: 0.7869 | Val Loss: 0.8446 | Val mIoU: 0.6769
# Epoch 6/100 | Train Loss: 0.7169 | Val Loss: 0.7760 | Val mIoU: 0.6889
# Epoch 7/100 | Train Loss: 0.6660 | Val Loss: 0.7322 | Val mIoU: 0.6992
# Epoch 8/100 | Train Loss: 0.6313 | Val Loss: 0.6059 | Val mIoU: 0.7482
# Epoch 9/100 | Train Loss: 0.6140 | Val Loss: 0.6174 | Val mIoU: 0.7647
# Epoch 10/100 | Train Loss: 0.5977 | Val Loss: 0.7007 | Val mIoU: 0.7385
# Epoch 11/100 | Train Loss: 0.5917 | Val Loss: 0.6828 | Val mIoU: 0.7402
# Epoch 12/100 | Train Loss: 0.5806 | Val Loss: 0.5497 | Val mIoU: 0.8050
#   Saved new best model with mIoU 0.8050
# Epoch 13/100 | Train Loss: 0.5770 | Val Loss: 0.7582 | Val mIoU: 0.7250
# Epoch 14/100 | Train Loss: 0.5692 | Val Loss: 0.5693 | Val mIoU: 0.8121
#   Saved new best model with mIoU 0.8121
# Epoch 15/100 | Train Loss: 0.5593 | Val Loss: 0.6115 | Val mIoU: 0.7768
# Epoch 16/100 | Train Loss: 0.5613 | Val Loss: 0.6959 | Val mIoU: 0.7446
# Epoch 17/100 | Train Loss: 0.5833 | Val Loss: 0.5916 | Val mIoU: 0.8014
# Epoch 18/100 | Train Loss: 0.5613 | Val Loss: 0.5856 | Val mIoU: 0.8136
#   Saved new best model with mIoU 0.8136
# Epoch 19/100 | Train Loss: 0.5558 | Val Loss: 0.6270 | Val mIoU: 0.7861
# Epoch 20/100 | Train Loss: 0.5446 | Val Loss: 0.5648 | Val mIoU: 0.8264
#   Saved new best model with mIoU 0.8264
# Epoch 21/100 | Train Loss: 0.5332 | Val Loss: 0.6194 | Val mIoU: 0.7964
# Epoch 22/100 | Train Loss: 0.5320 | Val Loss: 0.6624 | Val mIoU: 0.7457
# Epoch 23/100 | Train Loss: 0.5192 | Val Loss: 0.6934 | Val mIoU: 0.7499
# Epoch 24/100 | Train Loss: 0.5080 | Val Loss: 0.6240 | Val mIoU: 0.8102
# Epoch 25/100 | Train Loss: 0.5122 | Val Loss: 0.7799 | Val mIoU: 0.7400
# Epoch 26/100 | Train Loss: 0.5036 | Val Loss: 0.8673 | Val mIoU: 0.7062
# Epoch 27/100 | Train Loss: 0.5064 | Val Loss: 0.8162 | Val mIoU: 0.7175
# Epoch 28/100 | Train Loss: 0.4900 | Val Loss: 1.0058 | Val mIoU: 0.7100
# Epoch 29/100 | Train Loss: 0.4991 | Val Loss: 0.7550 | Val mIoU: 0.7621
# Epoch 30/100 | Train Loss: 0.4934 | Val Loss: 0.8198 | Val mIoU: 0.7338
# Epoch 31/100 | Train Loss: 0.4797 | Val Loss: 0.8132 | Val mIoU: 0.7456
# Epoch 32/100 | Train Loss: 0.4743 | Val Loss: 0.7190 | Val mIoU: 0.7927
# Epoch 33/100 | Train Loss: 0.4831 | Val Loss: 0.9383 | Val mIoU: 0.7120
# Epoch 34/100 | Train Loss: 0.5032 | Val Loss: 0.8246 | Val mIoU: 0.7269
# Epoch 35/100 | Train Loss: 0.4871 | Val Loss: 0.9211 | Val mIoU: 0.7162
# Epoch 36/100 | Train Loss: 0.4696 | Val Loss: 0.9709 | Val mIoU: 0.6897
# Epoch 37/100 | Train Loss: 0.4696 | Val Loss: 0.7240 | Val mIoU: 0.8197
# Epoch 38/100 | Train Loss: 0.4757 | Val Loss: 0.7023 | Val mIoU: 0.8101
# Epoch 39/100 | Train Loss: 0.4889 | Val Loss: 0.8843 | Val mIoU: 0.7460
# Epoch 40/100 | Train Loss: 0.4711 | Val Loss: 0.7937 | Val mIoU: 0.7449
# Epoch 41/100 | Train Loss: 0.4466 | Val Loss: 0.9712 | Val mIoU: 0.7072
# Epoch 42/100 | Train Loss: 0.4368 | Val Loss: 1.1236 | Val mIoU: 0.6812
# Epoch 43/100 | Train Loss: 0.4507 | Val Loss: 0.8953 | Val mIoU: 0.7387
# Epoch 44/100 | Train Loss: 0.4448 | Val Loss: 0.8625 | Val mIoU: 0.7445
# Epoch 45/100 | Train Loss: 0.4402 | Val Loss: 0.7885 | Val mIoU: 0.7750
# Epoch 46/100 | Train Loss: 0.4688 | Val Loss: 0.9253 | Val mIoU: 0.7474
# Epoch 47/100 | Train Loss: 0.4978 | Val Loss: 1.0285 | Val mIoU: 0.6809
# Epoch 48/100 | Train Loss: 0.5536 | Val Loss: 0.8639 | Val mIoU: 0.7274
# Epoch 49/100 | Train Loss: 0.5199 | Val Loss: 0.7223 | Val mIoU: 0.7809
# Epoch 50/100 | Train Loss: 0.4899 | Val Loss: 0.9172 | Val mIoU: 0.7189
# Epoch 51/100 | Train Loss: 0.4805 | Val Loss: 0.7205 | Val mIoU: 0.7782
# Epoch 52/100 | Train Loss: 0.4610 | Val Loss: 0.7555 | Val mIoU: 0.7797
# Epoch 53/100 | Train Loss: 0.4393 | Val Loss: 0.9487 | Val mIoU: 0.7255
# Epoch 54/100 | Train Loss: 0.4395 | Val Loss: 0.9329 | Val mIoU: 0.7207
# Epoch 55/100 | Train Loss: 0.4289 | Val Loss: 0.9569 | Val mIoU: 0.7301
# Epoch 56/100 | Train Loss: 0.4417 | Val Loss: 0.8977 | Val mIoU: 0.6978
# Epoch 57/100 | Train Loss: 0.4477 | Val Loss: 0.8809 | Val mIoU: 0.7489
# Epoch 58/100 | Train Loss: 0.4225 | Val Loss: 0.9306 | Val mIoU: 0.7104
# Epoch 59/100 | Train Loss: 0.4150 | Val Loss: 0.8138 | Val mIoU: 0.7378
# Epoch 60/100 | Train Loss: 0.4294 | Val Loss: 0.9561 | Val mIoU: 0.7062
# Epoch 61/100 | Train Loss: 0.4174 | Val Loss: 0.8749 | Val mIoU: 0.7010
# Epoch 62/100 | Train Loss: 0.4305 | Val Loss: 0.7356 | Val mIoU: 0.8146
# Epoch 63/100 | Train Loss: 0.4234 | Val Loss: 0.8588 | Val mIoU: 0.7223
# Epoch 64/100 | Train Loss: 0.4147 | Val Loss: 0.8760 | Val mIoU: 0.7327
# Epoch 65/100 | Train Loss: 0.4223 | Val Loss: 0.8485 | Val mIoU: 0.6942
# Epoch 66/100 | Train Loss: 0.4211 | Val Loss: 1.1105 | Val mIoU: 0.7330
# Epoch 67/100 | Train Loss: 0.4227 | Val Loss: 0.7521 | Val mIoU: 0.7737
# Epoch 68/100 | Train Loss: 0.3960 | Val Loss: 0.9289 | Val mIoU: 0.7550
# Epoch 69/100 | Train Loss: 0.4227 | Val Loss: 0.7398 | Val mIoU: 0.8637
#   Saved new best model with mIoU 0.8637
# Epoch 70/100 | Train Loss: 0.4073 | Val Loss: 0.9456 | Val mIoU: 0.6825
# Epoch 71/100 | Train Loss: 0.4001 | Val Loss: 1.0342 | Val mIoU: 0.6035
# Epoch 72/100 | Train Loss: 0.4085 | Val Loss: 0.8204 | Val mIoU: 0.8301
# Epoch 73/100 | Train Loss: 0.4064 | Val Loss: 0.8463 | Val mIoU: 0.7112
# Epoch 74/100 | Train Loss: 0.3969 | Val Loss: 1.0522 | Val mIoU: 0.6701
# Epoch 75/100 | Train Loss: 0.3930 | Val Loss: 0.9182 | Val mIoU: 0.7134
# Epoch 76/100 | Train Loss: 0.3853 | Val Loss: 0.9971 | Val mIoU: 0.7051
# Epoch 77/100 | Train Loss: 0.3786 | Val Loss: 0.8856 | Val mIoU: 0.7016
# Epoch 78/100 | Train Loss: 0.3816 | Val Loss: 1.0592 | Val mIoU: 0.6627
# Epoch 79/100 | Train Loss: 0.3774 | Val Loss: 0.8694 | Val mIoU: 0.7448
# Epoch 80/100 | Train Loss: 0.3764 | Val Loss: 1.0344 | Val mIoU: 0.6914
# Epoch 81/100 | Train Loss: 0.3773 | Val Loss: 0.9759 | Val mIoU: 0.6812
# Epoch 82/100 | Train Loss: 0.3853 | Val Loss: 1.1536 | Val mIoU: 0.5761
# Epoch 83/100 | Train Loss: 0.3759 | Val Loss: 0.9627 | Val mIoU: 0.7185
# Epoch 84/100 | Train Loss: 0.3950 | Val Loss: 0.9582 | Val mIoU: 0.6283
# Epoch 85/100 | Train Loss: 0.3822 | Val Loss: 0.8538 | Val mIoU: 0.7042
# Epoch 86/100 | Train Loss: 0.3780 | Val Loss: 0.9770 | Val mIoU: 0.7569
# Epoch 87/100 | Train Loss: 0.4029 | Val Loss: 1.0811 | Val mIoU: 0.6643
# Epoch 88/100 | Train Loss: 0.3953 | Val Loss: 0.9592 | Val mIoU: 0.6709
# Epoch 89/100 | Train Loss: 0.3750 | Val Loss: 0.9866 | Val mIoU: 0.7053
# Epoch 90/100 | Train Loss: 0.3620 | Val Loss: 1.2080 | Val mIoU: 0.5644
# Epoch 91/100 | Train Loss: 0.3801 | Val Loss: 0.8474 | Val mIoU: 0.7974
# Epoch 92/100 | Train Loss: 0.3847 | Val Loss: 0.9405 | Val mIoU: 0.7411
# Epoch 93/100 | Train Loss: 0.3791 | Val Loss: 1.0798 | Val mIoU: 0.6865
# Epoch 94/100 | Train Loss: 0.3876 | Val Loss: 0.9666 | Val mIoU: 0.7403
# Epoch 95/100 | Train Loss: 0.3923 | Val Loss: 0.9859 | Val mIoU: 0.7100
# Epoch 96/100 | Train Loss: 0.3914 | Val Loss: 0.8733 | Val mIoU: 0.7155
# Epoch 97/100 | Train Loss: 0.3905 | Val Loss: 1.0066 | Val mIoU: 0.6738
# Epoch 98/100 | Train Loss: 0.3832 | Val Loss: 0.8885 | Val mIoU: 0.7602
# Epoch 99/100 | Train Loss: 0.3789 | Val Loss: 0.9538 | Val mIoU: 0.7076
# Epoch 100/100 | Train Loss: 0.3915 | Val Loss: 0.8283 | Val mIoU: 0.7231
#
# ✅ Final Test mIoU: 0.6945
# 📊 Final Test mIoU Summary:
# ╒══════════════════════╤═════════════╕
# │ Training Data Used   │   Test mIoU │
# ╞══════════════════════╪═════════════╡
# │ 100.0% Data          │      0.9044 │
# ├──────────────────────┼─────────────┤
# │ 50.0% Data           │      0.868  │
# ├──────────────────────┼─────────────┤
# │ 25.0% Data           │      0.8571 │
# ├──────────────────────┼─────────────┤
# │ 10.0% Data           │      0.6945 │
# ╘══════════════════════╧═════════════╛
